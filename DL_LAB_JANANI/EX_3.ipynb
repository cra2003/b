# %%
import pandas as pd
d1=pd.read_csv(r"/home/ai_ds-a2/Desktop/data.csv")

# %%
d1
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
d1['price_range'].unique()
# Out:
# array([1, 2, 3, 0])

# %% [markdown]
# ## 4 LAYERS-adam (2-hidden)---accuracy:0.76

# %%
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers, models
x = d1.drop('price_range', axis=1)
y = d1['price_range']

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
model = models.Sequential()
model.add(layers.Dense(128, activation='relu', input_shape=(X_train.shape[1],)))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(32, activation='relu'))
model.add(layers.Dense(4,activation='softmax'))  

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
model.fit(X_train, y_train, epochs=100,validation_data=(X_test,y_test), validation_split=0.2)
# Out:
# Epoch 1/100
# 50/50 [==============================] - 1s 3ms/step - loss: 15.9620 - accuracy: 0.4275 - val_loss: 6.4282 - val_accuracy: 0.3950
# Epoch 2/100
# 50/50 [==============================] - 0s 1ms/step - loss: 3.6415 - accuracy: 0.4663 - val_loss: 1.8564 - val_accuracy: 0.5325
# Epoch 3/100
# 50/50 [==============================] - 0s 2ms/step - loss: 1.9167 - accuracy: 0.5294 - val_loss: 2.3503 - val_accuracy: 0.3975
# Epoch 4/100
# 50/50 [==============================] - 0s 2ms/step - loss: 1.8421 - accuracy: 0.5256 - val_loss: 2.0286 - val_accuracy: 0.4600
# Epoch 5/100
# 50/50 [==============================] - 0s 2ms/step - loss: 1.4886 - accuracy: 0.5788 - val_loss: 1.2164 - val_accuracy: 0.5650
# Epoch 6/100
# 50/50 [==============================] - 0s 2ms/step - loss: 1.2201 - accuracy: 0.5981 - val_loss: 1.4390 - val_accuracy: 0.6050
# Epoch 7/100
# ...

# %%
eval=model.evaluate(X_test,y_test)
print("Accuracy : ", eval[1])
# Out:
# 13/13 [==============================] - 0s 859us/step - loss: 0.5187 - accuracy: 0.7700
# Accuracy :  0.7699999809265137

# %% [markdown]
# ## 5 LAYERS-adam (3-hidden)---accuracy:0.26

# %%
model1 = models.Sequential()

model1.add(layers.Dense(128, activation='relu', input_shape=(X_train.shape[1],)))
model1.add(layers.Dense(64, activation='relu'))
model1.add(layers.Dense(32, activation='relu'))
model1.add(layers.Dense(16, activation='relu'))

model1.add(layers.Dense(4,activation='softmax'))  

model1.compile(optimizer='sgd',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
model1.fit(X_train, y_train, epochs=100,validation_data=(X_test,y_test), validation_split=0.2)
# Out:
# Epoch 1/100
# 50/50 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.2488 - val_loss: nan - val_accuracy: 0.2625
# Epoch 2/100
# 50/50 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.2469 - val_loss: nan - val_accuracy: 0.2625
# Epoch 3/100
# 50/50 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.2469 - val_loss: nan - val_accuracy: 0.2625
# Epoch 4/100
# 50/50 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.2469 - val_loss: nan - val_accuracy: 0.2625
# Epoch 5/100
# 50/50 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.2469 - val_loss: nan - val_accuracy: 0.2625
# Epoch 6/100
# 50/50 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.2469 - val_loss: nan - val_accuracy: 0.2625
# Epoch 7/100
# 50/50 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.2469 - val_loss: nan - val_accuracy: 0.2625
# Epoch 8/100
# ...

# %%
eval=model1.evaluate(X_test,y_test)
print("Accuracy : ", eval[1])
# Out:
# 13/13 [==============================] - 0s 862us/step - loss: nan - accuracy: 0.2625
# Accuracy :  0.26249998807907104

# %% [markdown]
# ## 3 LAYERS-adam (1-hidden)

# %%
model2 = models.Sequential()

model2.add(layers.Dense(128, activation='relu', input_shape=(X_train.shape[1],)))
model2.add(layers.Dense(64, activation='relu'))
model2.add(layers.Dense(4,activation='softmax'))  

model2.compile(optimizer='sgd',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
model2.fit(X_train, y_train, epochs=100,validation_data=(X_test,y_test), validation_split=0.2)
# Out:
# Epoch 1/100
# 50/50 [==============================] - 0s 3ms/step - loss: 53479.5039 - accuracy: 0.2419 - val_loss: 1.3873 - val_accuracy: 0.2300
# Epoch 2/100
# 50/50 [==============================] - 0s 1ms/step - loss: 1.3863 - accuracy: 0.2519 - val_loss: 1.3875 - val_accuracy: 0.2300
# Epoch 3/100
# 50/50 [==============================] - 0s 1ms/step - loss: 1.3863 - accuracy: 0.2450 - val_loss: 1.3877 - val_accuracy: 0.2300
# Epoch 4/100
# 50/50 [==============================] - 0s 1ms/step - loss: 1.3863 - accuracy: 0.2500 - val_loss: 1.3879 - val_accuracy: 0.2300
# Epoch 5/100
# 50/50 [==============================] - 0s 1ms/step - loss: 1.3862 - accuracy: 0.2400 - val_loss: 1.3880 - val_accuracy: 0.2300
# Epoch 6/100
# 50/50 [==============================] - 0s 1ms/step - loss: 1.3862 - accuracy: 0.2512 - val_loss: 1.3882 - val_accuracy: 0.2275
# Epoch 7/100
# ...

# %%
eval=model2.evaluate(X_test,y_test)
print("Accuracy : ", eval[1])
# Out:
# 13/13 [==============================] - 0s 825us/step - loss: 1.3893 - accuracy: 0.2275
# Accuracy :  0.22750000655651093

# %% [markdown]
# ## 4 LAYERS-sgd (2-hidden)

# %%
model3 = models.Sequential()

model3.add(layers.Dense(128, activation='relu', input_shape=(X_train.shape[1],)))
model3.add(layers.Dense(64, activation='relu'))
model3.add(layers.Dense(32, activation='relu'))
model3.add(layers.Dense(4,activation='softmax'))  

model3.compile(optimizer='sgd',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
model3.fit(X_train, y_train, epochs=100,validation_data=(X_test,y_test), validation_split=0.2)
# Out:
# Epoch 1/100
# 50/50 [==============================] - 0s 3ms/step - loss: 215260172685293450690560.0000 - accuracy: 0.2463 - val_loss: 1.3873 - val_accuracy: 0.2300
# Epoch 2/100
# 50/50 [==============================] - 0s 1ms/step - loss: 1.3863 - accuracy: 0.2550 - val_loss: 1.3874 - val_accuracy: 0.2300
# Epoch 3/100
# 50/50 [==============================] - 0s 1ms/step - loss: 1.3862 - accuracy: 0.2550 - val_loss: 1.3875 - val_accuracy: 0.2300
# Epoch 4/100
# 50/50 [==============================] - 0s 1ms/step - loss: 1.3862 - accuracy: 0.2550 - val_loss: 1.3877 - val_accuracy: 0.2300
# Epoch 5/100
# 50/50 [==============================] - 0s 1ms/step - loss: 1.3862 - accuracy: 0.2456 - val_loss: 1.3877 - val_accuracy: 0.2300
# Epoch 6/100
# 50/50 [==============================] - 0s 1ms/step - loss: 1.3862 - accuracy: 0.2531 - val_loss: 1.3878 - val_accuracy: 0.2300
# Epoch 7/100
# ...

# %%
eval=model3.evaluate(X_test,y_test)
print("Accuracy : ", eval[1])
# Out:
# 13/13 [==============================] - 0s 854us/step - loss: 1.3885 - accuracy: 0.2275
# Accuracy :  0.22750000655651093
